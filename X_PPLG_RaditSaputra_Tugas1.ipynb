# %% [markdown]
# <a href="https://colab.research.google.com/github/RaditSaputraRpl/DasarPPLG-X-2026/blob/main/X_PPLG_RaditSaputra_Tugas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Tugas 1 Praktik Membuat Tipe Data dan Variable
# C.Tugas 1 Praktik 1: Membuat type data dan variabel**
#
# Nama kelompok:Jawa Barat
#
# Nama anggota:
# 1. Alliyah Herawati
# 2. Hayun Hasanah
# 3. Alvino Setyawan Ramadhan
# 4. Miftahul Hilmi
# 5. Radit Saputra
# 6. M. Shal Alfaraz

# %%
# !g++ --version
# Out:
# g++ (Ubuntu 13.3.0-6ubuntu2~24.04.1) 13.3.0
# Copyright (C) 2023 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# %%writefile praktik_variabel.cpp
# #include <iostream>
# #include <string>
# using namespace std;
#
# int main() {
#     // Deklarasi Variabel dan Tipe Data
#     string namaBarang = "Laptop Lenovo";
#     int jumlah = 2;
#     float harga = 750000.50;
#     char kategori = 'A';
#     bool tersedia = true;
#
#     // Menampilkan Output ke Layar
#     cout << "=== DATA INVENTARIS ===" << endl;
#     cout << "Nama Barang : " << namaBarang << endl;
#     cout << "Kategori    : " << kategori << endl;
#     cout << "Jumlah      : " << jumlah << endl;
#     cout << "Harga       : Rp " << harga << endl;
#     cout << "Tersedia    : " << tersedia << " (1 = Ya, 0 = Tidak)" << endl;
#     cout << "=======================" << endl;
#
#     return 0;
# }
# Out:
# Overwriting praktik_variabel.cpp

# %%
# !g++ praktik_variabel.cpp -o praktik_variabel

# %%
# !./praktik_variabel
# Out:
# === DATA INVENTARIS ===
# Nama Barang : Laptop Lenovo
# Kategori    : A
# Jumlah      : 2
# Harga       : Rp 750000
# Tersedia    : 1 (1 = Ya, 0 = Tidak)
# ...
